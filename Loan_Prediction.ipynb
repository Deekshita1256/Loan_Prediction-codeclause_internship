# %% [markdown]
# Loan Prediction system

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/Test Dataset.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Urban           Y
# 2             1.0         Urban           N
# 3             NaN         Urban           Y
# 4             1.0         Urban           Y

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
#  12  Loan_Status        367 non-null    object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 37.4+ KB

# %%
# find the null values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# fill the missing values for numerical terms - mean
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mean())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
# fill the missing values for categorical terms - mode
df['Gender'] = df["Gender"].fillna(df['Gender'].mode()[0])
df['Dependents'] = df["Dependents"].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df["Self_Employed"].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
counts = df["Gender"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Married"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Dependents"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Education"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Self_Employed"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Property_Area"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
counts = df["Loan_Status"].value_counts()
plt.bar(counts.index, counts.values)
plt.show()

# %%
# numerical attributes visualization
sns.distplot(df["ApplicantIncome"])
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.distplot(df["CoapplicantIncome"])
# Out:
# <Axes: xlabel='CoapplicantIncome', ylabel='Density'>

# %%
sns.distplot(df["LoanAmount"])
# Out:
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# <Axes: xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
sns.distplot(df['Credit_History'])
# Out:
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
# total income
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income
# 0        1.000000         Urban           Y          5720
# 1        1.000000         Urban           Y          4576
# 2        1.000000         Urban           N          6800
# 3        0.825444         Urban           Y          4886
# 4        1.000000         Urban           Y          3276

# %%
# apply log transformation to the attribute
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome']+1)
sns.distplot(df["ApplicantIncomeLog"])
# Out:
# <Axes: xlabel='ApplicantIncomeLog', ylabel='Density'>

# %%
df['CoapplicantIncomeLog'] = np.log(df['CoapplicantIncome']+1)
sns.distplot(df["CoapplicantIncomeLog"])
# Out:
# <Axes: xlabel='CoapplicantIncomeLog', ylabel='Density'>

# %%
df['LoanAmountLog'] = np.log(df['LoanAmount']+1)
sns.distplot(df["LoanAmountLog"])
# Out:
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term']+1)
sns.distplot(df["Loan_Amount_Term_Log"])
# Out:
# <Axes: xlabel='Loan_Amount_Term_Log', ylabel='Density'>

# %%
df['Total_Income_Log'] = np.log(df['Total_Income']+1)
sns.distplot(df["Total_Income_Log"])
# Out:
# <Axes: xlabel='Total_Income_Log', ylabel='Density'>

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot = True, cmap="BuPu")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# 0        1.000000         Urban           Y          5720            8.651899
# 1        1.000000         Urban           Y          4576            8.031710
# 2        1.000000         Urban           N          6800            8.517393
# 3        0.825444         Urban           Y          4886            7.758333
# 4        1.000000         Urban           Y          3276            8.094684
#
#    CoapplicantIncomeLog  LoanAmountLog  Loan_Amount_Term_Log  Total_Income_Log
# 0              0.000000       4.709530              5.888878          8.651899
# 1              7.313887       4.844187              5.888878          8.428799
# 2              7.496097       5.342334              5.888878          8.824825
# 3              7.842671       4.615121              5.888878          8.494334
# 4              0.000000       4.369448              5.888878          8.094684

# %%
# drop unnecessary columns
cols = ['ApplicantIncome', 'CoapplicantIncome', "LoanAmount", "Loan_Amount_Term", "Total_Income", 'Loan_ID', 'CoapplicantIncomeLog']
df = df.drop(columns=cols, axis=1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male     Yes          0      Graduate            No        1.000000
# 1   Male     Yes          1      Graduate            No        1.000000
# 2   Male     Yes          2      Graduate            No        1.000000
# 3   Male     Yes          2      Graduate            No        0.825444
# 4   Male      No          0  Not Graduate            No        1.000000
#
#   Property_Area Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y            8.651899       4.709530
# 1         Urban           Y            8.031710       4.844187
# 2         Urban           N            8.517393       5.342334
# 3         Urban           Y            7.758333       4.615121
# 4         Urban           Y            8.094684       4.369448
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.651899
# 1              5.888878          8.428799
# 2              5.888878          8.824825
# 3              5.888878          8.494334
# 4              5.888878          8.094684

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender',"Married","Education",'Self_Employed',"Property_Area","Loan_Status","Dependents"]
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        1           0          0              0        1.000000
# 1       1        1           1          0              0        1.000000
# 2       1        1           2          0              0        1.000000
# 3       1        1           2          0              0        0.825444
# 4       1        0           0          1              0        1.000000
#
#    Property_Area  Loan_Status  ApplicantIncomeLog  LoanAmountLog  \
# 0              2            1            8.651899       4.709530
# 1              2            1            8.031710       4.844187
# 2              2            0            8.517393       5.342334
# 3              2            1            7.758333       4.615121
# 4              2            1            8.094684       4.369448
#
#    Loan_Amount_Term_Log  Total_Income_Log
# 0              5.888878          8.651899
# 1              5.888878          8.428799
# 2              5.888878          8.824825
# 3              5.888878          8.494334
# 4              5.888878          8.094684

# %%
# specify input and output attributes
X = df.drop(columns=['Loan_Status'], axis=1)
y = df['Loan_Status']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# classify function
from sklearn.model_selection import cross_val_score
def classify(model, x, y):
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
    model.fit(x_train, y_train)
    print("Accuracy is", model.score(x_test, y_test)*100)
    # cross validation - it is used for better validation of model
    # eg: cv-5, train-4, test-1
    score = cross_val_score(model, x, y, cv=5)
    print("Cross validation is",np.mean(score)*100)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, X, y)
# Out:
# Accuracy is 66.30434782608695
# Cross validation is 68.3931877082562

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
classify(model, X, y)
# Out:
# Accuracy is 57.608695652173914
# Cross validation is 55.883006293965195

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
model = RandomForestClassifier()
classify(model, X, y)
# Out:
# Accuracy is 66.30434782608695
# Cross validation is 59.696408737504626

# %% [markdown]
# Extra Tree Classifier

# %%
model = ExtraTreesClassifier()
classify(model, X, y)
# Out:
# Accuracy is 60.86956521739131
# Cross validation is 57.77489818585708

# %% [markdown]
# Random Forest with attributes values

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=25, max_depth=7, max_features=1)
classify(model, X, y)
# Out:
# Accuracy is 65.21739130434783
# Cross validation is 68.3931877082562

# %%
print(" Accuracy  ")
print("Logistic regression  : 66.30434782608695 ")
print("Decision trees       : 57.608695652173914")
print("Random forest        : 66.30434782608695")
print("Extra tree classifier: 60.86956521739131")
# Out:
#  Accuracy
# Logistic regression  : 66.30434782608695
# Decision trees       : 57.608695652173914
# Random forest        : 66.30434782608695
# Extra tree classifier: 60.86956521739131

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(x_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 4, 27],
#        [ 5, 56]])

# %%
sns.heatmap(cm, annot=True)
# Out:
# <Axes: >
